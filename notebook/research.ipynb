# %% [markdown]
# ### ConfigBox package

# %%
d = {'key1': 'value1', 'key2': 'value2'}

# %%
d['key1']
# Out:
# 'value1'

# %%
d.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 d.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
from box import ConfigBox

# %%
d2 = {'key1': 'value1', 'key2': 'value2'}

# %%
d2 = ConfigBox(d2)

# %%
d2.key1
# Out:
# 'value1'

# %%
d2['key1']
# Out:
# 'value1'

# %% [markdown]
# ### ensure annotations package

# %%
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x = 2, y = 3)
# Out:
# 6

# %%
get_product(x=2, y='3')
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x = 2, y = 3)
# Out:
# 6

# %%
get_product(x=2, y='3')
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 get_product(x=2, y='3')
#
# File c:\projects_endtoend\chest_cancer_detection\cnn_env\lib\site-packages\ensure\main.py:803, in WrappedFunction.__call__(self, *args, **kwargs)
#     798     if not isinstance(value, templ):
#     799         msg = (
#     800             "Argument {arg} of type {valt} to {f} "
#     801             "does not match annotation type {t}"
#     802         )
# --> 803         raise EnsureError(msg.format(
#     804             arg=arg, f=self.f, t=templ, valt=type(value)
#     805         ))
#     807 return self.f(*args, **kwargs)
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x000001BD4F7DC9D0> does not match annotation type <class 'int'>

# %% [markdown]
# ### Download data from google drive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1lLbSqACVv2eC_kjKyqCLvy9Rn4y2qx7N/view?usp=drive_link"

# %%
type(url)
# Out:
# str

# %%
url.split("/")
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'file',
#  'd',
#  '1lLbSqACVv2eC_kjKyqCLvy9Rn4y2qx7N',
#  'view?usp=drive_link']

# %%
## extract file id

file_id = url.split("/")[-2]
file_id
# Out:
# '1lLbSqACVv2eC_kjKyqCLvy9Rn4y2qx7N'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix + file_id, 'chest-x-ray-data.zip')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1lLbSqACVv2eC_kjKyqCLvy9Rn4y2qx7N
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1lLbSqACVv2eC_kjKyqCLvy9Rn4y2qx7N&confirm=t&uuid=03669a1e-29f7-4e63-9eaf-68ec314952bd
# To: c:\projects_endtoend\chest_cancer_detection\notebook\chest-x-ray-data.zip
# 100%|██████████| 291M/291M [00:49<00:00, 5.84MB/s]
# 'chest-x-ray-data.zip'
